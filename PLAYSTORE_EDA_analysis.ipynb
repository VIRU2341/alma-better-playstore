# %% [markdown]
# <a href="https://colab.research.google.com/github/VIRU2341/alma-better-playstore/blob/main/PLAYSTORE_EDA_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - PLAYSTORE EDA  Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Project By**      - Virendra Singh Rawat

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The Play Store apps data has enormous potential to drive app-making busines to success. Actionable insights can be drawn for developers to work on and capture the Android market. Each app (row) has values for category, rating, size, and more. Another dataset contains customer reviews of the android apps. Explore analyse the data to discover key factors responsible for app engagement = success.
# First we will  import the important libraries  than clean the data using various function than we will visualize the data by making different charts and than finally comes to the solution and conclusion for the developers to work on and capture the android market.
# Overall, the Play Store App  Analysis is a valuable for app developers and business owners who want to understand user feedback and improve their apps. By providing insights into the most important recommendations that how to improve the app, the project can help businesses increase user satisfaction and drive growth.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/VIRU2341/alma-better-playstore.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Lets explore and analyze the dataset and find some insights.**
#
# 1.How many number of app per category?
#
# 2.How many number of installs per category?
#
# 3.What are the types of distribution whether there are free apps or paid apps?
#
# 4.What are the different ratings given to different apps?
#
# 5.Correlation between the different columns?
#
# Finally this information will be used to provide insights and recommendations on how to improve app , retain users, increase revenue, and enhance marketing strategies. Ultimately, my goal is to help businesses create successful apps that satisfy their customers and drive growth.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# My task is to explore and analyse the data to discover the important factors of the apps such as rating,reviews, size, installation,types genres and many more.finally come to the conclusion for the developers to focus on the important factors which is playing the major role in the success or failure of the app.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Play Store Data.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10836       Everyone          Education     July 25, 2017                1.48
# 10837       Everyone          Education      July 6, 2018                 1.0
# 10838       Everyone            Medical  January 20, 2017                 1.0
# 10839     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10840       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (10841, 13)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()
# Out:
# 483

# %%
#dropping the duplicate values
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (10358, 13)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1465
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
# now visualizing the missing values of play_store_data using seaborn heatmap
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# From the above data we can see that there are 10358 rows and 13 columns with missing/null values in rating(1465) column.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#             Rating
# count  8893.000000
# mean      4.189542
# std       0.545452
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# App : The name of the app
#
# Category : The category of the app
#
# Rating : The rating of the app in the Play Store
#
# Reviews : The number of reviews of the app
#
# Size : The size of the app
#
# Install : The number of installs of the app
#
# Type : The type of the app (Free/Paid)
#
# The price of the app (0 if it is Free)
#
# Content Rating :The appropiate target audience of the app
#
# Genres: The genre of the app
#
# Last Updated : The date when the app was last updated
#
# Current Ver : The current version of the app
#
# Android Ver : The minimum Android version required to run the app

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
pd.Series({col:df[col].unique() for col in df})
# Out:
# App               [Photo Editor & Candy Camera & Grid & ScrapBoo...
# Category          [ART_AND_DESIGN, AUTO_AND_VEHICLES, BEAUTY, BO...
# Rating            [4.1, 3.9, 4.7, 4.5, 4.3, 4.4, 3.8, 4.2, 4.6, ...
# Reviews           [159, 967, 87510, 215644, 167, 178, 36815, 137...
# Size              [19M, 14M, 8.7M, 25M, 2.8M, 5.6M, 29M, 33M, 3....
# Installs          [10,000+, 500,000+, 5,000,000+, 50,000,000+, 1...
# Type                                           [Free, Paid, nan, 0]
# Price             [0, $4.99, $3.99, $6.99, $1.49, $2.99, $7.99, ...
# Content Rating    [Everyone, Teen, Everyone 10+, Mature 17+, Adu...
# Genres            [Art & Design, Art & Design;Pretend Play, Art ...
# Last Updated      [January 7, 2018, January 15, 2018, August 1, ...
# Current Ver       [1.0.0, 2.0.0, 1.2.4, Varies with device, 1.1,...
# Android Ver       [4.0.3 and up, 4.2 and up, 4.4 and up, 2.3 and...
# dtype: object

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# creating a new empty dataframe to new variable
dfnew = pd.DataFrame(index=df.columns)

# now adding datatype, not_null, and null columns to play_store_data_new
dfnew["DataType"] = df.dtypes
dfnew["not_null"] = df.count()
dfnew["null"] = df.isnull().sum()

# printing the dataframe
dfnew
# Out:
#                DataType  not_null  null
# App              object     10358     0
# Category         object     10358     0
# Rating          float64      8893  1465
# Reviews          object     10358     0
# Size             object     10358     0
# Installs         object     10358     0
# Type             object     10357     1
# Price            object     10358     0
# Content Rating   object     10357     1
# Genres           object     10358     0
# Last Updated     object     10358     0
# Current Ver      object     10350     8
# Android Ver      object     10355     3

# %%
# checking the rating of play_store_data
df.boxplot()
# Out:
# <Axes: >

# %%
df[(df['Rating'] <1) | (df['Rating']>5)]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %% [markdown]
# There is some problem is this row the app rating is 19,that is why we're droping this row.

# %%
df.drop(10472,axis=0,inplace=True)

# %%
# checking it is removed or not
df.boxplot();

# %% [markdown]
# In this play store dataset, there is still 1465 null values in "Rating" that is why we have to fix them so for this first we find the mean and median.

# %%
# finding the mean of Rating column from play_store_data
rating_mean = df['Rating'].mean()
print(f"The mean of Rating column is {rating_mean}")

# now finding the median of Rating column from play_store_data
rating_median = df['Rating'].median()
print(f"The median of Rating column is {rating_median}")
# Out:
# The mean of Rating column is 4.187876743139902
# The median of Rating column is 4.3

# %% [markdown]
# Here is not much difference between mean and median, that's why we'll replace all the null values with median because it shows that 50% of apps have more than 4.3 rating.

# %%
# filling all the null values by the median in Rating column of play_store_data
df['Rating'].fillna(value=rating_median,inplace=True)

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       2
# dtype: int64

# %%
# checking the Type's NaN value in Type column of play_store_data
df[(df['Type'].isnull())]
# Out:
#                             App Category  Rating Reviews                Size  \
# 9148  Command & Conquer: Rivals   FAMILY     4.3       0  Varies with device
#
#      Installs Type Price Content Rating    Genres   Last Updated  \
# 9148        0  NaN     0   Everyone 10+  Strategy  June 28, 2018
#
#              Current Ver         Android Ver
# 9148  Varies with device  Varies with device

# %%
# counting the free and paid versions of applications in play_store_data
df['Type'].value_counts()
# Out:
# Free    9591
# Paid     765
# Name: Type, dtype: int64

# %%
# now we replace the NaN value of Type
df.loc[9148,'Type']='Free'

# %%
#  checking it is fixed or not
df[(df['Type'].isnull())]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
# fixing the Current Ver's null values in play_store_data
df[(df['Current Ver'].isnull())]
# Out:
#                                    App             Category  Rating Reviews  \
# 15     Learn To Draw Kawaii Characters       ART_AND_DESIGN     3.2      55
# 1553              Market Update Helper   LIBRARIES_AND_DEMO     4.1   20145
# 6322            Virtual DJ Sound Mixer                TOOLS     4.2    4010
# 6803                         BT Master               FAMILY     4.3       0
# 7333                       Dots puzzle               FAMILY     4.0     179
# 7407                   Calculate My IQ               FAMILY     4.3      44
# 7730                            UFO-CQ                TOOLS     4.3       1
# 10342                   La Fe de Jesus  BOOKS_AND_REFERENCE     4.3       8
#
#        Size    Installs  Type  Price Content Rating             Genres  \
# 15     2.7M      5,000+  Free      0       Everyone       Art & Design
# 1553    11k  1,000,000+  Free      0       Everyone   Libraries & Demo
# 6322   8.7M    500,000+  Free      0       Everyone              Tools
# 6803   222k        100+  Free      0       Everyone          Education
# 7333    14M     50,000+  Paid  $0.99       Everyone             Puzzle
# 7407   7.2M     10,000+  Free      0       Everyone      Entertainment
# 7730   237k         10+  Paid  $0.99       Everyone              Tools
# 10342  658k      1,000+  Free      0       Everyone  Books & Reference
#
#             Last Updated Current Ver Android Ver
# 15          June 6, 2018         NaN  4.2 and up
# 1553   February 12, 2013         NaN  1.5 and up
# 6322        May 10, 2017         NaN  4.0 and up
# 6803    November 6, 2016         NaN  1.6 and up
# 7333      April 18, 2018         NaN  4.0 and up
# 7407       April 3, 2017         NaN  2.3 and up
# 7730        July 4, 2016         NaN  2.0 and up
# 10342   January 31, 2017         NaN  3.0 and up

# %%
# droping all the NaN values of Current Ver column from play_store_data
df.drop([15,1553,6322,6803,7333,7407,7730,10342],axis=0,inplace=True)

# checking all the Nan values are droped or not
df[(df['Current Ver'].isnull())]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
# checking the Android Ver's NaN value which is shown when we used this commmand: print(play_store_data.isnull().sum())
df[(df['Android Ver'].isnull())]
# Out:
#                          App         Category  Rating Reviews  Size Installs  \
# 4453  [substratum] Vacuum: P  PERSONALIZATION     4.4     230   11M   1,000+
# 4490    Pi Dark [substratum]  PERSONALIZATION     4.5     189  2.1M  10,000+
#
#       Type  Price Content Rating           Genres    Last Updated Current Ver  \
# 4453  Paid  $1.49       Everyone  Personalization   July 20, 2018         4.4
# 4490  Free      0       Everyone  Personalization  March 27, 2018         1.1
#
#      Android Ver
# 4453         NaN
# 4490         NaN

# %% [markdown]
# ##Handling the Data Types for Every Columns##

# %%
# checking the data type in Size column in play_store_data
df['Size']
# Out:
# 0                       19M
# 1                       14M
# 2                      8.7M
# 3                       25M
# 4                      2.8M
#                 ...
# 10836                   53M
# 10837                  3.6M
# 10838                  9.5M
# 10839    Varies with device
# 10840                   19M
# Name: Size, Length: 10349, dtype: object

# %% [markdown]
# The "Size" has different units.
#
# M means MB
# K means KB
#
# So We'll fix this using convert them into single unit.

# %%
# cleaning and converting 'Size' to numeric
def clean_size(x):
    if 'Varies with device' in str(x):
        return np.nan
    elif 'k' in str(x):
        return float(str(x).replace('k', '')) / 1024
    else:
        return float(str(x).replace('M', ''))


df['Size'] = df['Size'].apply(clean_size)

# %%
# checking the data type in Price column in play_store_data
df['Price'].value_counts()
# Out:
# 0          9586
# $0.99       144
# $2.99       125
# $1.99        73
# $4.99        70
#            ...
# $389.99       1
# $19.90        1
# $1.75         1
# $14.00        1
# $1.04         1
# Name: Price, Length: 92, dtype: int64

# %% [markdown]
# The $ sign maybe a problem in "Price" so We'll remove them.

# %%
# we're trying to remove dollar sign from Price
def remove_from_price(b):
    if type(b) == str and '$' in b:
        b = b.replace('$', '')
    return b

df['Price'] = df['Price'].apply(remove_from_price)

# %%
# checking the data type in Installs column in play_store_data
df['Installs'].value_counts()
# Out:
# 1,000,000+        1487
# 10,000,000+       1132
# 100,000+          1129
# 10,000+           1032
# 1,000+             889
# 100+               709
# 5,000,000+         683
# 500,000+           516
# 50,000+            473
# 5,000+             468
# 10+                384
# 100,000,000+       369
# 500+               328
# 50,000,000+        272
# 50+                204
# 5+                  82
# 1+                  67
# 500,000,000+        61
# 1,000,000,000+      49
# 0+                  14
# 0                    1
# Name: Installs, dtype: int64

# %% [markdown]
# In this "Installs" we have to remove these signs: +(plus) and ,(comma)

# %%
# we're trying to remove +(plus) and ,(comma) from Installs
def remove_from_install(a):
    if type(a) == str:
        a = a.replace(',', '').replace('+', '')
    return a

df['Installs'] = df['Installs'].apply(remove_from_install)

# %%
# cleaning and converting 'Installs' to numeric
df['Installs'] = df['Installs'].replace('[^\d]', '', regex=True).astype(float)


# cleaning and converting 'Price' to numeric
df['Price'] = df['Price'].replace('[^\d\.]', '', regex=True).astype(float)

# time to print
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10349 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10349 non-null  object
#  1   Category        10349 non-null  object
#  2   Rating          10349 non-null  float64
#  3   Reviews         10349 non-null  object
#  4   Size            8823 non-null   float64
#  5   Installs        10349 non-null  float64
#  6   Type            10349 non-null  object
#  7   Price           10349 non-null  float64
#  8   Content Rating  10349 non-null  object
#  9   Genres          10349 non-null  object
#  10  Last Updated    10349 non-null  object
#  11  Current Ver     10349 non-null  object
#  12  Android Ver     10347 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 1.1+ MB

# %% [markdown]
# ##Removing duplicates apps##

# %%
# using head()
df.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size    Installs  Type  Price Content Rating  \
# 0     159  19.0     10000.0  Free    0.0       Everyone
# 1     967  14.0    500000.0  Free    0.0       Everyone
# 2   87510   8.7   5000000.0  Free    0.0       Everyone
# 3  215644  25.0  50000000.0  Free    0.0           Teen
# 4     967   2.8    100000.0  Free    0.0       Everyone
# 5     167   5.6     50000.0  Free    0.0       Everyone
# 6     178  19.0     50000.0  Free    0.0       Everyone
# 7   36815  29.0   1000000.0  Free    0.0       Everyone
# 8   13791  33.0   1000000.0  Free    0.0       Everyone
# 9     121   3.1     10000.0  Free    0.0       Everyone
#
#                       Genres        Last Updated         Current Ver  \
# 0               Art & Design     January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play    January 15, 2018               2.0.0
# 2               Art & Design      August 1, 2018               1.2.4
# 3               Art & Design        June 8, 2018  Varies with device
# 4    Art & Design;Creativity       June 20, 2018                 1.1
# 5               Art & Design      March 26, 2017                 1.0
# 6               Art & Design      April 26, 2018                 1.1
# 7               Art & Design       June 14, 2018            6.1.61.1
# 8               Art & Design  September 20, 2017               2.9.2
# 9    Art & Design;Creativity        July 3, 2018                 2.8
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up
# 5    2.3 and up
# 6  4.0.3 and up
# 7    4.2 and up
# 8    3.0 and up
# 9  4.0.3 and up

# %%
# checking the values of App from play_store_data
df['App'].value_counts()
# Out:
# ROBLOX                                           9
# 8 Ball Pool                                      7
# Zombie Catchers                                  6
# Bubble Shooter                                   6
# Helix Jump                                       6
#                                                 ..
# Popsicle Launcher for Android P 9.0 launcher     1
# PixelLab - Text on pictures                      1
# P Launcher for Android™ 9.0                      1
# Pacify (Android P theme) - Theme for Xperia™     1
# iHoroscope - 2018 Daily Horoscope & Astrology    1
# Name: App, Length: 9651, dtype: int64

# %%
# calculating the duplicate value in "App" column in play_store_data
df['App'].duplicated().sum()
# Out:
# 698

# %% [markdown]
# Here are 1181 dublicates values in column which we'll remove.

# %%
# dropping duplicates value in "App" in play_store_data
df.drop_duplicates(subset='App',inplace=True)
df['App'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##2nd Step: Data Cleaning on User Review dataset##

# %%
# now we're importing the User Reviews.csv from Google Drive as user_reviews_data
user_reviews_data = pd.read_csv('/content/drive/MyDrive/User Reviews.csv')

# %%
# using head() to show top 10 rows of user_reviews_data
user_reviews_data.head(10)
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
# 5  10 Best Foods for You                                           Best way
# 6  10 Best Foods for You                                            Amazing
# 7  10 Best Foods for You                                                NaN
# 8  10 Best Foods for You                               Looking forward app,
# 9  10 Best Foods for You              It helpful site ! It help foods get !
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000
# 5  Positive                1.00                0.300000
# 6  Positive                0.60                0.900000
# 7       NaN                 NaN                     NaN
# 8   Neutral                0.00                0.000000
# 9   Neutral                0.00                0.000000

# %%
# using tail() to show last 10 rows of user_reviews_data
user_reviews_data.tail(10)
# Out:
#                                App Translated_Review Sentiment  \
# 64285  Houzz Interior Design Ideas               NaN       NaN
# 64286  Houzz Interior Design Ideas               NaN       NaN
# 64287  Houzz Interior Design Ideas               NaN       NaN
# 64288  Houzz Interior Design Ideas               NaN       NaN
# 64289  Houzz Interior Design Ideas               NaN       NaN
# 64290  Houzz Interior Design Ideas               NaN       NaN
# 64291  Houzz Interior Design Ideas               NaN       NaN
# 64292  Houzz Interior Design Ideas               NaN       NaN
# 64293  Houzz Interior Design Ideas               NaN       NaN
# 64294  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 64285                 NaN                     NaN
# 64286                 NaN                     NaN
# 64287                 NaN                     NaN
# 64288                 NaN                     NaN
# 64289                 NaN                     NaN
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN

# %%
# checking the shape (number of rows and columns) of user_reviews_data
user_reviews_data.shape
# Out:
# (64295, 5)

# %%
# checking the columns of user_reviews_data
user_reviews_data.columns
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %% [markdown]
# **The dataset has 5 columns are identified as below:
# App: Title of the application.**
#
# Translated_Review: It contains the English translation of the review.
#
# Sentiment: It gives the emotion like 'Positive', 'Negative', or 'Neutral'.
#
# Sentiment_Polarity: It gives the polarity of the review. Its range is [-1,1], where 1 means 'Positive statement' and -1 means a 'Negative statement'.
#
# Sentiment_Subjectivity: This value gives how close a reviewers opinion is to the opinion of the general public. Its range is[0,1].

# %%
# using the info of user_reviews_data
user_reviews_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
# creating a new empty dataframe to new variable
user_reviews_data_new = pd.DataFrame(index=user_reviews_data.columns)

# now adding datatype, not_null, and null columns to user_reviews_data_new
user_reviews_data_new["DataType"] = user_reviews_data.dtypes
user_reviews_data_new["not_null"] = user_reviews_data.count()
user_reviews_data_new["null"] = user_reviews_data.isnull().sum()

# printing the dataframe
user_reviews_data_new
# Out:
#                        DataType  not_null   null
# App                      object     64295      0
# Translated_Review        object     37427  26868
# Sentiment                object     37432  26863
# Sentiment_Polarity      float64     37432  26863
# Sentiment_Subjectivity  float64     37432  26863

# %%
# finding the NaN value of Sentiment_Polarity column in user_reviews_data
user_reviews_data[(user_reviews_data['Sentiment_Polarity'].isnull())]
# Out:
#                                App Translated_Review Sentiment  \
# 2            10 Best Foods for You               NaN       NaN
# 7            10 Best Foods for You               NaN       NaN
# 15           10 Best Foods for You               NaN       NaN
# 102          10 Best Foods for You               NaN       NaN
# 107          10 Best Foods for You               NaN       NaN
# ...                            ...               ...       ...
# 64290  Houzz Interior Design Ideas               NaN       NaN
# 64291  Houzz Interior Design Ideas               NaN       NaN
# 64292  Houzz Interior Design Ideas               NaN       NaN
# 64293  Houzz Interior Design Ideas               NaN       NaN
# 64294  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 2                     NaN                     NaN
# 7                     NaN                     NaN
# 15                    NaN                     NaN
# 102                   NaN                     NaN
# 107                   NaN                     NaN
# ...                   ...                     ...
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN
#
# [26863 rows x 5 columns]

# %%
# counting the values of Sentiment_Polarity from user_reviews_data
user_reviews_data['Sentiment_Polarity'].value_counts()
# Out:
#  0.000000    5163
#  0.500000    1524
#  0.700000     991
#  1.000000     959
#  0.800000     639
#              ...
# -0.072024       1
#  0.452000       1
#  0.076190       1
# -0.067256       1
#  0.173333       1
# Name: Sentiment_Polarity, Length: 5410, dtype: int64

# %%
# droping all null values from user_reviews_data
user_reviews_data.dropna(inplace = True)

# %%
# time to check is there any null values now
user_reviews_data[(user_reviews_data['Sentiment_Polarity'].isnull())]
# Out:
# Empty DataFrame
# Columns: [App, Translated_Review, Sentiment, Sentiment_Polarity, Sentiment_Subjectivity]
# Index: []

# %%
# now time to check the data as little cleaned or not
user_reviews_data.head(20)
# Out:
#                       App                                  Translated_Review  \
# 0   10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1   10 Best Foods for You    This help eating healthy exercise regular basis
# 3   10 Best Foods for You         Works great especially going grocery store
# 4   10 Best Foods for You                                       Best idea us
# 5   10 Best Foods for You                                           Best way
# 6   10 Best Foods for You                                            Amazing
# 8   10 Best Foods for You                               Looking forward app,
# 9   10 Best Foods for You              It helpful site ! It help foods get !
# 10  10 Best Foods for You                                          good you.
# 11  10 Best Foods for You  Useful information The amount spelling errors ...
# 12  10 Best Foods for You  Thank you! Great app!! Add arthritis, eyes, im...
# 13  10 Best Foods for You  Greatest ever Completely awesome maintain heal...
# 14  10 Best Foods for You  Good health...... Good health first priority.....
# 16  10 Best Foods for You  Health It's important world either life . thin...
# 17  10 Best Foods for You  Mrs sunita bhati I thankful developers,to make...
# 18  10 Best Foods for You  Very Useful in diabetes age 30. I need control...
# 19  10 Best Foods for You                                 One greatest apps.
# 20  10 Best Foods for You                                          good nice
# 21  10 Best Foods for You                              Healthy Really helped
# 22  10 Best Foods for You                                         God health
#
#    Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0   Positive            1.000000                0.533333
# 1   Positive            0.250000                0.288462
# 3   Positive            0.400000                0.875000
# 4   Positive            1.000000                0.300000
# 5   Positive            1.000000                0.300000
# 6   Positive            0.600000                0.900000
# 8    Neutral            0.000000                0.000000
# 9    Neutral            0.000000                0.000000
# 10  Positive            0.700000                0.600000
# 11  Positive            0.200000                0.100000
# 12  Positive            0.750000                0.875000
# 13  Positive            0.992188                0.866667
# 14  Positive            0.550000                0.511111
# 16  Positive            0.450000                1.000000
# 17  Positive            0.600000                0.666667
# 18  Positive            0.295000                0.100000
# 19  Positive            1.000000                1.000000
# 20  Positive            0.650000                0.800000
# 21  Positive            0.350000                0.350000
# 22   Neutral            0.000000                0.000000

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# **In the For the play_store_data, we did these manipulations.**
#
# **1.**We checked the first and last 10 rows of the dataset using head() and tail() to get an idea of the data, then used shape to check the dimensions of the dataset, columns to get the column names, and info() to see data types and any null values.
#
# **2.**We found and removed 483 duplicate values to ensure data accuracy.
#
# **3.**We discovered 1464 null values in the "Rating" column and replaced them with the median value, as it is a better representation of central tendency than the mean, which can be skewed by outliers.
#
# **4.**We also dropped one row that had a rating of 19, which was not possible as the maximum rating is 5.
#
# **5.**We removed 1 null value from the "Type" column, 8 null values from the "Current Ver" column, and 2 null values from the "Android Ver" column.
#
# **6.**We noticed that there were 10,039 free apps that had a price of 0, so we replaced the price value with the keyword "Free" for clarity.
#
# **7.**We removed unnecessary characters such as "M" and "K" from the "Size" column, "$" sign from "Price" column, and "+" and "," from "Installs" column to make the data more consistent and easy to read.
#
# **8.**We discovered 698 duplicate apps in the "App" column and removed them to avoid redundancy and ensure data accuracy.
#
#
# **In the For the user_reviews_data, we did these manipulations.**
#
# **1.**We checked the first and last 20 rows of the dataset using head() and tail() to get an idea of the data, then used shape to check the dimensions of the dataset, columns to get the column names, and info() to see data types and any null values.
#
# **2.**We found NaN values in the "Sentiment_Polarity" column and dropped all null values from the dataset using dropna, as these are categorical values and cannot be imputed with a value.
#
# **From above those manipulations, we found these Insights.**
#
# **1.**From the play_store_data, we found that the majority of apps are free, with over 9591 apps being free and only 765 being paid. Additionally, we found that there were 698 duplicate app entries, so we removed them from the dataset.
#
# **2.**We also discovered that the Rating column had 1465 missing values, which we replaced with the median value. Moreover, there were 483 duplicate rows that we removed.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
Category=df["Category"].value_counts()
Category.head()
print(Category)
# Chart - 1 visualization code
Category.plot(kind="bar",figsize=(15,6),fontsize=13)
plt.title("category app in playstore",fontsize=15)
plt.xlabel("Category",fontsize=15)
plt.ylabel("counts",fontsize=15)
plt.show()
# Out:
# FAMILY                 1829
# GAME                    959
# TOOLS                   825
# BUSINESS                420
# MEDICAL                 395
# PRODUCTIVITY            374
# PERSONALIZATION         374
# LIFESTYLE               369
# FINANCE                 345
# SPORTS                  325
# COMMUNICATION           315
# HEALTH_AND_FITNESS      288
# PHOTOGRAPHY             281
# NEWS_AND_MAGAZINES      254
# SOCIAL                  239
# BOOKS_AND_REFERENCE     221
# TRAVEL_AND_LOCAL        219
# SHOPPING                202
# DATING                  171
# VIDEO_PLAYERS           163
# MAPS_AND_NAVIGATION     131
# EDUCATION               119
# FOOD_AND_DRINK          112
# ENTERTAINMENT           102
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       83
# WEATHER                  79
# HOUSE_AND_HOME           74
# EVENTS                   64
# ART_AND_DESIGN           63
# PARENTING                60
# COMICS                   56
# BEAUTY                   53
# Name: Category, dtype: int64

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I used this chart to compare and count the different category of apps.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above chart it can be seen clearly that the family app in playstore is the most 1943 and the least app is beauty i,e 53.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The chart above shows that  most of the apps in the play store are from the categories of Family, 'Game' and also 'Tools.

# %% [markdown]
# #### Chart - 2

# %%
# Chart -2 visualization code
# merge the datasets
merged_data = pd.merge(df, user_reviews_data, on='App')

# grouping the data by category and sum the installs
category_installs = merged_data.groupby('Category')['Installs'].sum().reset_index()

# sorting the data by installs in descending order
category_installs = category_installs.sort_values('Installs', ascending=False)

# creating a barplot using seaborn lib
sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(10,8))
ax = sns.barplot(x='Category', y='Installs', data=category_installs)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right", fontsize=10)
ax.set_xlabel('Category', fontsize=12)
ax.set_ylabel('Installs', fontsize=12)
ax.set_title('App Categories with the Most Installs', fontsize=14)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is a good choice for visualizing the number of installs for different app categories because it allows us for easy comparison between categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In this visualization, we can see that the most downloaded applications belong to the GAME category, indicating a high demand for GAMES. After GAMES, there is a strong competition between PHOTOGRAPHY and COMMUNICATION applications.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#   The GAMES category  apps are in high demand. Similarly, companies operating in the PHOTOGRAPHY and COMMUNICATION categories are the strong competition and innovate their products to stand out in the market and capture more customers. This can help them improve their market position and increase their revenue.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

# merge the data on the app
merged_data = pd.merge(df, user_reviews_data, on='App')

# creating a histogram of the app ratings
plt.hist(merged_data["Rating"], bins=20)

# adding labels and title
plt.xlabel("App Rating")
plt.ylabel("Frequency")
plt.title("Distribution of App Ratings")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a bar chart because it is an effective way to display counts or frequencies of categorical data, such as app ratings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most apps have a rating between 4.0 and 4.5, which means that users are mostly happy with them. There are only a few apps with ratings below 3.5.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Here most apps have high ratings, indicating that users are generally satisfied with the quality of apps available on the Play Store. This could result in increased user trust, which can lead to higher app downloads, increased revenue, and a better overall reputation for the app store.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

# merge the data on the app
merged_data = pd.merge(df, user_reviews_data, on='App')

# calculating the number of reviews by category
reviews_by_category = merged_data.groupby("Category")["Translated_Review"].count().sort_values(ascending=False)

# creating a horizontal bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x=reviews_by_category.values, y=reviews_by_category.index)
plt.xlabel("Number of Reviews")
plt.ylabel("Category")
plt.title("Number of Reviews by Category")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I used the horizontal bar chart to visualize the distribution of reviews across different app categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Users typically leave reviews for an application after using it, and we can see that the GAME category has the highest number of reviews. This suggests that the GAME category has a large and engaged user base.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It highlights the importance of providing a positive user experience in order to encourage users to leave reviews, which can ultimately lead to increased visibility and downloads for an app.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
# grouping data by category and type
category_counts = df.groupby(['Category', 'Type']).count()['App'].unstack()

# ploting stacked bar chart
category_counts.plot(kind='bar', stacked=True)
plt.title("Distribution of Free vs. Paid Apps by Category")
plt.xlabel("Category")
plt.ylabel("Number of Apps")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I used the stacked bar chart because it allows for a clear comparison between the number of free and paid apps in each category

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Developers and apps creator in popular categories like "FAMILY", "GAMES", and "TOOLS" should explore other revenue options because these categories have a high number of free apps, making it challenging to generate income solely through app purchases.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This information can help developers and businesses make better decisions about which categories to focus on. If they want to create a paid app, they might want to focus on the "Family" or "Game" categories. But if they want to create a free app with less competition, they could consider the "Beauty," "Art and Design," and "Comics" categories.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# grouping play_store_data by category and finding the mean of size
mean_size_by_category = df.groupby("Category")["Size"].mean() / 1000000
plt.figure(figsize=(12,8))
mean_size_by_category.plot(kind='bar')
plt.xticks(rotation=90)
plt.title("Average App Size by Category")
plt.xlabel("Category")
plt.ylabel("Average App Size (MB)")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I used the bar chart because it is a simple and effective way to compare the average app size in different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The biggest apps are in the "Game" and "Family" categories, while the smallest apps are in the "Tools" and "Libraries and Demo" categories.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It helps app developers to better optimize the size of their app according to their target category, as well as give them insights on the size of their competitors' apps in the same category. Also, make sure their apps are not too big and take up too much space on users' devices.

# %% [markdown]
# #### Chart - 7

# %%
# merge the data on the app
merged_data = pd.merge(df, user_reviews_data, on='App')

free_vs_paid_app = merged_data[merged_data['Type'].isin(['Free', 'Paid'])]

# now using the violin plot
sns.boxplot(x='Type', y='Rating', data=free_vs_paid_app, palette=['#66b3ff', '#ffcc99'])

# title of violin plot
plt.title('Average Rating of Free vs. Paid Apps')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I  use  boxplot because it can show the distribution of data for both free and paid apps, as well as the average rating of each.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Both "FREE" and "PAID" apps have a similar average rating of about 4.3. However, "FREE" apps have a wider range of ratings than"PAID" apps, meaning there is more variation in their ratings. On the other hand, "PAID" apps have a more consistent rating, with fewer extreme ratings. This information can be helpful for users when deciding whether to download a free or "PAID" app.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This information can help a company decide whether to offer their app for "FREE" or charge for it. If they want consistent ratings, they may choose to charge for the app. If they want a wider audience, they may choose to offer the app for "FREE", even if there may be more variability in the reviews.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
# content rating of the apps
data = df['Content Rating'].value_counts()
labels = ['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+','Adults only 18+', 'Unrated']

# using pie chart
plt.figure(figsize=(10,6))
plt.pie(data, labels = labels, autopct='%.2f%%',textprops={'fontsize': 15})
plt.title('Content Rating',size=20,loc='center')
plt.legend();

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Pie Chart is a great choice for visualizing the distribution of categories in the 'Content Rating' column.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most of the apps on the play store have a content rating of 'Everyone' (81.80%). This is followed by 'Teen' (10.74%), 'Everyone 10+' (4.07%), 'Mature 17+' (3.34%), 'Adults only 18+' (0.03%), and 'Unrated' (0.02%).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This information can help app developers to know that the majority of apps have a 'Everyone' rating, which allows for a broad audience. But for businesses targeting specific age groups, like 'Mature 17+' or 'Adults only 18+', this information can be useful as there is less competition in those areas.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# creating a variable and storing the each unique values of Type
paid_or_free = df['Type'].value_counts()
labels = df['Type'].value_counts().index

# creating a pie chart
plt.figure(figsize=(10,8))
plt.pie(paid_or_free,labels=labels,autopct='%.2f%%',shadow=True,textprops={'fontsize': 15})
plt.title('Free Vs Paid Apps')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie carts are a good choice for visualizing categorical data like the distribution of free vs. paid apps.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most apps in the Play Store dataset are free (92.20%), while only a small percentage are paid (7.80%). This suggests that users prefer free apps.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The high percentage of free apps in the Play Store suggests that offering free apps can be a successful business strategy to attract users.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
# converting "Last Updated" column to datetime format
df["Last Updated"] = pd.to_datetime(df["Last Updated"])

# calculating the percentage of apps that were updated within the last 30 days
last_30_days = df[df["Last Updated"] >= (pd.Timestamp.now() - pd.Timedelta(days=30))]
updated_apps_percent = len(last_30_days) / len(df) * 100

# create a pie chart to visualize the percentage of apps that are updated frequently
plt.figure(figsize=(6,6))
plt.pie([updated_apps_percent, 100-updated_apps_percent], labels=["Updated within last 30 days", "Not updated within last 30 days"], autopct='%1.1f%%')
plt.title("Percentage of Apps Updated Frequently")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I used the pie chart because it's a great way to visualize the percentage of apps that are updated frequently.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# No apps were updated in the last 30 days. This suggests that app developers may need to update their apps more often to keep users happy and engaged.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Not updating apps for a long time can be bad for businesses because users may lose interest and switch to other apps. Regular updates can also provide important security patches, which reduce the risk of hacking. That's why, businesses should prioritize updating their apps regularly and always provide updates to users to maintain their interest and ensure the security of their data.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
from matplotlib.ticker import PercentFormatter
# merge the data on the app by inner
merged_df = pd.merge(df, user_reviews_data, on='App', how = 'inner')
merged_df.head()
f = plt.figure(figsize=(15,8))
ax = f.add_subplot(1,1,1)

# using seaborn lib to show stacked histogram
sns.histplot(
    data=merged_df,
    x="Category", hue="Sentiment",
    bins=34,
    ax=ax,
    stat="count",
    multiple="stack",
    palette="light:m_r",
    edgecolor=".3",
    linewidth=.5,
    legend=True
    )


ax.set_title("Sentiment Analysis Based on Category",fontsize=15,fontweight='bold')
plt.xticks(rotation='vertical')
ax.set_xlabel("Category",fontsize=14)
ax.set_ylabel("Review Counts",fontsize=14)

plt.gca().yaxis.set_major_formatter(PercentFormatter(20000))
sns.set(style="ticks")
plt.grid()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We used Stacked Histogram because it helps to visualize the sentiment analysis based on categories in the reviews data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It tell us which app categories have the most positive and negative reviews. Seems like the "GAME" category has the most reviews, both positive and negative. However, there are more negative reviews than positive ones, so the developers of those apps should figure out what is causing the negative experiences and fix them. On the other hand, the "COMICS" category has very few reviews, both positive and negative.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Businesses can identify the areas that need improvement in their apps. This can help them improve their apps and provide better user experiences, which can lead to increased customer satisfaction and loyalty. As a result, it can have a positive impact on their business's reputation and potentially increase their revenue.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# merge the data on the app
merged_data = pd.merge(df, user_reviews_data, on='App')

# calculating the revenue by category
merged_data['Revenue'] = merged_data['Installs'] * merged_data['Price']
revenue_by_category = merged_data.groupby('Category')['Revenue'].sum()

# convert revenue to million
revenue_by_category /= 1000000

# sorting by revenue in descending order
revenue_by_category = revenue_by_category.sort_values(ascending=False)

# adding custom color palette with 6 colors
custom_palette = sns.color_palette(['#4c72b0', '#55a868', '#c44e52', '#8172b2', '#ccb974', '#64b5cd'])

# now using bar chart of revenue by category
plt.figure(figsize=(10, 6))
sns.barplot(x=revenue_by_category.index, y=revenue_by_category.values, palette=custom_palette)
plt.xticks(rotation=90)
plt.xlabel("Category")
plt.ylabel("Revenue (Millions)")
plt.title("Revenue by Category")

# adding actual revenue values to the bar chart
for i, val in enumerate(revenue_by_category.values):
    plt.annotate("{:.2f}".format(val), (i, val), ha='center', va='bottom', fontsize=8)

# now time to print
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# i used this bar chart because it's an effective way to visualize the revenue generated by each category in a clear way.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It shows that the "Personalization" category generates the highest revenue, followed by "Sports" and "Medical". This information can be valuable for companies that create apps in these categories as they can prioritize their investments and efforts accordingly.
#
# On the other hand, some categories, such as "Weather" and "Beauty", generate lower revenue. This indicates that businesses working in these categories may need to explore alternative revenue streams or rethink their business strategy.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Companies can prioritize their investments and efforts in categories that generate the highest revenue, such as "Personalization", "Sports", and "Medical". Whereas those companies which are operating in categories with lower revenue, such as "Weather" and "Beauty", may face challenges in generating significant profits solely through the Play Store. They may need to explore other revenue options or adjust their business strategy accordingly.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
# content rating of the apps
install = df['Installs'].value_counts()
print(install.head(10))
plt.subplots(figsize=(25,16))
plt.xticks(rotation=90)
ax = sns.countplot(x="Installs", data=df, palette="Set3")
# Out:
# 1000000.0     1416
# 100000.0      1112
# 10000.0       1030
# 10000000.0     937
# 1000.0         887
# 100.0          709
# 5000000.0      607
# 500000.0       504
# 50000.0        468
# 5000.0         467
# Name: Installs, dtype: int64

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To compare the number of installation.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insight is that upto 10Lk installation is the highest.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insight is that app below 5000 installation must be on focused,there might be some issue,that the insallation is less.Playstore must figure out such app and solve the issue.

# %% [markdown]
# #### Chart - 14

# %%
# Chart - 14 visualization code
# merge the data on the app by inner
merged_df = pd.merge(df, user_reviews_data, on='App', how='inner')

# selecting the columns which we have to show on plot
columns = ['Rating', 'Reviews', 'Size', 'Installs', 'Price']

# now creating the pair plot
sns.pairplot(data=merged_df[columns])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The Pair Plot is a good choice for exploratory data analysis as it allows us to visualize the relationships between different columns in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Apps with smaller sizes tend to have higher ratings from users, while those with larger sizes tend to have lower ratings.
#
# 1.As the price increases, the installation rate decreases.
#
# 2.Apps with a rating between 4 and 5 have more reviews compared to apps with lower ratings.
#
# 3.Also, Apps with ratings between 4 and 5 have been installed more.
#
# 4.As the price of the app increases, the number of reviews or users also decreases.

# %% [markdown]
# #### Chart - 15 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# generating heatmap of correlation
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),annot=True)
plt.title("Correlation by Heatmap in Play Store Data",size='20');
# Out:
# <ipython-input-87-c71d9138a91a>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We used Correlation Heatmap because it helps to understand the correlation between the columns in Play Store Data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The number of app installs and the number of reviews have a strong positive connection, which means that when there are more reviews, there are generally more app installs. The study showed that when an app has more installs, it usually has more reviews too. However, the study also found that as the price of an app increases, fewer people tend to install it.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# As per EDA shown above,
#
# **1**. Businesses should focus on developing and improving apps in popular categories like games, photography, and communication, and find ways to differentiate their apps from competitors to increase their chances of success.
#
# **2**. Businesses should aim to maintain high app ratings between 4.0 and 4.5, and prioritize improving apps with ratings below 3.5 to increase user satisfaction. This could be achieved by gathering user feedback and addressing any issues or bugs, as well as implementing new features or improvements to enhance the overall user experience.
#
# **3**. Businesses should focus on app categories with a high number of user reviews, such as games, health and fitness, and family, as these categories have a large and engaged user base. For categories with a similar number of reviews, such as dating and travel and local, businesses should consider other factors such as user satisfaction and competition when developing or improving apps in these categories.
#
# **4**. Developers and businesses should explore other revenue options in popular categories such as family, games, and tools, as these categories have a high number of free apps, making it challenging to generate income solely through app purchases. They could consider implementing in-app advertisements or offering in-app purchases to users to increase revenue. Additionally, businesses could also explore other monetization models such as subscriptions or partnerships with other businesses to generate revenue.
#
# **5**. Users should consider both the average rating and rating distribution when deciding whether to download a free or paid app. While both types of apps have similar average ratings, free apps have a wider range of ratings, indicating more variation in user satisfaction. Paid apps, on the other hand, have a more consistent rating with fewer extreme ratings. This information can help users make informed decisions when deciding between free and paid apps.
#
# **6**. Companies that create apps in high-revenue categories like personalization, sports, and medical should prioritize their investments and efforts accordingly to maximize revenue. However, businesses working in lower revenue categories like weather and beauty may need to explore alternative revenue streams or rethink their business strategy. By analyzing revenue generation by category, businesses can make informed decisions about where to invest their resources and identify areas for potential improvement or growth.
#
# **7**. Users should be aware that apps in different categories have different average sizes, with games and family apps typically being larger, and tools and libraries and demo apps being smaller. This information can help users make informed decisions when managing their device storage, as they may need to prioritize which apps to keep or uninstall based on their storage needs. Additionally, businesses developing apps in categories with larger average sizes may need to consider optimizing their app size to improve user experience and avoid potential storage concerns.
#
# **8**. App developers should consider updating their apps more frequently to keep users engaged and satisfied. The lack of updates in the last 30 days suggests that app developers may not be prioritizing updates, which could lead to user dissatisfaction and decreased engagement. By analyzing the frequency of app updates, developers can identify potential areas for improvement and prioritize updates to improve user experience and engagement.
#
#  **9**.Developers should focus on improving the user experience and encouraging positive reviews to increase app installs. They should also consider pricing strategies that attract users while generating revenue.
#
#  **10**.Developers can use this information to optimize their app size, pricing, and ratings to improve user engagement and drive more installs and positive reviews. They can also use this data to benchmark their app's performance against industry standards and competitors.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Developers should focus on developing and improving apps in popular categories like games, photography, and communication, while maintaining high app ratings and prioritizing user feedback to improve the overall user experience. They should also explore other revenue options in popular categories and update their apps frequently to keep users engaged and satisfied.
#
# Users should consider both the average rating and rating distribution when deciding whether to download a free or paid app and be aware that apps in different categories have different average sizes. They should also pay attention to app content ratings and prioritize their device storage needs when managing their apps.
#
# Businesses should prioritize their investments and efforts in high-revenue categories while being mindful of user demand and competition. They should also consider alternative revenue streams and rethink their business strategy if working in lower revenue categories.
#
# Overall, the app market is highly competitive, and developers and businesses must continually strive to improve their apps' quality and user experience to stand out in the crowded market. Users, on the other hand, can make informed decisions about which apps to download based on ratings, reviews, size, and content rating, among other factors.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
